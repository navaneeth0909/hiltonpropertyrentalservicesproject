# %%
pwd
# Out:
# 'C:\\Users\\Akash\\Downloads\\DE Demo Project'

# %%
import pandas as pd
df=pd.read_csv('BS.2.csv')
for i in range(len(df['price'])) :
    num=df.at[i, 'price'][1:]
    if len(num)>6 :
        num1=num[0]
        num2=num[2:]
        num=num1+num2
        
    df.at[i, 'price']=pd.to_numeric(num)
df.to_csv("BS.3.csv")

# %%
import pandas as pd
df=pd.read_csv('BS.3.csv')
df.pop('Unnamed: 0')
df.pop('Unnamed: 0.1')
df.pop('Unnamed: 0.1.1')
df['date']=pd.to_datetime(df['date'])
df.info()
df.to_csv("BS.4.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800841 entries, 0 to 1800840
# Data columns (total 4 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Property_id   int64
#  1   date          datetime64[ns]
#  2   availability  bool
#  3   price         float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 42.9 MB

# %%
df["availability"] = df["availability"].astype('bool')
df.to_csv("BS.2.csv")

# %%
print(df_new.keys())
for i in df_new.items():
    print(i)
# Out:
# Index(['Property_id', 'date', 'availability', 'price'], dtype='object')
# ('Property_id', 128            2015
# 129            2015
# 130            2015
# 131            2015
# 132            2015
#              ...
# 8231443    29809357
# 8231444    29809357
# 8231445    29809357
# 8231446    29809357
# 8231474    29809357
# Name: Property_id, Length: 1800841, dtype: int64)
# ('date', 128        2019-05-05
# 129        2019-05-04
# 130        2019-05-03
# 131        2019-05-02
# 132        2019-05-01
#               ...
# 8231443    2018-12-13
# 8231444    2018-12-12
# 8231445    2018-12-11
# 8231446    2018-12-10
# 8231474    2018-11-12
# Name: date, Length: 1800841, dtype: object)
# ('availability', 128        t
# 129        t
# 130        t
# 131        t
# 132        t
#           ..
# 8231443    t
# 8231444    t
# 8231445    t
# 8231446    t
# 8231474    t
# Name: availability, Length: 1800841, dtype: object)
# ('price', 128        $76.00
# 129        $76.00
# ...

# %%
import pandas as pd
df1=pd.read_csv('Feedbacksummary.csv',encoding='latin-1')
df_new=df1.dropna()
df_new.pop('Comments')
df_new.to_csv("FS.1.csv")

# %%
import pandas as pd
df1=pd.read_csv('FS.1.csv')
df1['Date']=pd.to_datetime(df1['Date'])
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401467 entries, 0 to 401466
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     401467 non-null  int64
#  1   Property_id    401467 non-null  int64
#  2   Id             401467 non-null  int64
#  3   Date           401467 non-null  datetime64[ns]
#  4   Reviewer_id    401467 non-null  int64
#  5   Reviewer_name  401467 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 18.4+ MB

# %%
df1["Reviewer_name"] = df1["Reviewer_name"].convert_dtypes()
df1.info()
df_new.to_csv("FS.2.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 401467 entries, 0 to 401466
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Unnamed: 0     401467 non-null  int64
#  1   Property_id    401467 non-null  int64
#  2   Id             401467 non-null  int64
#  3   Date           401467 non-null  datetime64[ns]
#  4   Reviewer_id    401467 non-null  int64
#  5   Reviewer_name  401467 non-null  string
# dtypes: datetime64[ns](1), int64(4), string(1)
# memory usage: 18.4 MB

# %%
import pandas as pd
df1=pd.read_csv('PropertySummary.csv')
for i in df1.keys():
    print(i)
# Out:
# Property_id
# Name
# Experiences_offered
# thumbnail_url
# medium_url
# xl_picture_url
# Attendent_id
# Attendent_name
# Attendent_since
# Attendent_location
# Attendent_response_time
# Attendent_response_rate
# Attendent_acceptance_rate
# Attendent_is_superAttendent
# Attendent_neighbourhood
# Attendent_Propertys_count
# Attendent_total_Propertys_count
# Attendent_verifications
# Attendent_has_profile_pic
# Attendent_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# zipcode
# country_code
# country
# latitude
# longitude
# is_location_exact
# property_type
# room_type
# accommodates
# bathrooms
# bedrooms
# beds
# bed_type
# amenities
# square_feet
# price
# weekly_price
# monthly_price
# security_deposit
# cleaning_fee
# guests_included
# extra_people
# minimum_nights
# maximum_nights
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# number_of_reviews
# first_review
# ...

# %%
import pandas as pd
df1=pd.read_csv('PropertySummary.csv')
df1.pop('thumbnail_url')
df1.pop('xl_picture_url')
df1.pop('medium_url')
df1.pop('Experiences_offered')
df1.pop('Attendent_acceptance_rate')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 66 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Property_id                       22552 non-null  int64
#  1   Name                              22493 non-null  object
#  2   Attendent_id                      22552 non-null  int64
#  3   Attendent_name                    22526 non-null  object
#  4   Attendent_since                   22526 non-null  float64
#  5   Attendent_location                22436 non-null  object
#  6   Attendent_response_time           9658 non-null   object
#  7   Attendent_response_rate           9657 non-null   float64
#  8   Attendent_is_superAttendent       22526 non-null  object
#  9   Attendent_neighbourhood           17458 non-null  object
#  10  Attendent_Propertys_count         22526 non-null  float64
# ...

# %%
df1.pop('reviews_per_month')
df1.pop('require_guest_phone_verification')
df1.pop('require_guest_profile_picture')
df1.pop('cancellation_policy')
df1.pop('is_business_travel_ready')
df1.pop('license')
df1.pop('requires_license')
df1.pop('last_review')
df1.pop('first_review')
df1.pop('calendar_updated')
df1.pop('bed_type')
df1.pop('square_feet')
df1.pop('is_location_exact')
df1.pop('country_code')
df1.pop('Attendent_has_profile_pic')
df1.pop('Attendent_verifications')
df1.pop('Attendent_identity_verified')
df1.pop('neighbourhood_cleansed')
df1.pop('neighbourhood_group_cleansed')
# Out:
#        Property_id                                               Name  \
# 0             2015      Top-Mitte Value! Quiet courtyard/very central
# 1             2695                 Prenzlauer Berg close to Mauerpark
# 2             3176                    Fabulous Flat in great Location
# 3             3309                     TopSpot Schöneberg near KaDeWe
# 4             7071                   BrightRoom with sunny greenview!
# ...            ...                                                ...
# 22547     29856708       Cozy Apartment right in the center of Berlin
# 22548     29857108             Altbau/ Schöneberger Kiez / Schlafsofa
# 22549     29864272   Artists loft with garden in the center of Berlin
# 22550     29866805              Room for two with private shower / WC
# 22551     29867352  Sunny, modern and cozy flat in Berlin Neukölln :)
#
#        Attendent_id Attendent_name  Attendent_since  \
# 0              2217            Ian          39678.0
# ...

# %%
df1.to_csv("PS.1.csv")

# %%
import pandas as pd
df=pd.read_csv('PS.1.csv')
df['Name']=df['Name'].convert_dtypes()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 48 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  object
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  object
#  7   Attendent_response_time          9658 non-null   object
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22526 non-null  object
#  10  Attendent_neighbourhood          17458 non-null  object
#  11  Attendent_Propertys_count        22526 non-null  float64
# ...

# %%
df['Attendent_name']=df['Attendent_name'].convert_dtypes()
df['Attendent_is_superAttendent']=df['Attendent_is_superAttendent'].astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 48 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  object
#  7   Attendent_response_time          9658 non-null   object
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_neighbourhood          17458 non-null  object
#  11  Attendent_Propertys_count        22526 non-null  float64
# ...

# %%
df['Attendent_location']=df['Attendent_location'].convert_dtypes()
df['Attendent_response_time']=df['Attendent_response_time'].convert_dtypes()
df['zipcode']=pd.to_numeric(df['zipcode'])
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
df.dropna(subset=['zipcode'])
# Out:
#        Unnamed: 0  Property_id  \
# 0               0         2015
# 1               1         2695
# 2               2         3176
# 3               3         3309
# 4               4         7071
# ...           ...          ...
# 22547       22547     29856708
# 22548       22548     29857108
# 22549       22549     29864272
# 22550       22550     29866805
# 22551       22551     29867352
#
#                                                     Name  Attendent_id  \
# 0          Top-Mitte Value! Quiet courtyard/very central          2217
# 1                     Prenzlauer Berg close to Mauerpark          2986
# 2                        Fabulous Flat in great Location          3718
# 3                         TopSpot Schöneberg near KaDeWe          4108
# 4                       BrightRoom with sunny greenview!         17391
# ...                                                  ...           ...
# 22547       Cozy Apartment right in the center of Berlin      87555909
# ...

# %%
df['zipcode']=10119
df['zipcode']=pd.to_numeric(df['zipcode'])
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
df.pop('country')
df.pop('property_type')
df.pop('room_type')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
df['has_availability']=df['has_availability'].astype(bool)
df['instant_bookable']=df['instant_bookable'].astype(bool)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 43 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
df.pop('minimum_nights')
df.pop('maximum_nights')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 41 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       22552 non-null  int64
#  1   Property_id                      22552 non-null  int64
#  2   Name                             22493 non-null  string
#  3   Attendent_id                     22552 non-null  int64
#  4   Attendent_name                   22526 non-null  string
#  5   Attendent_since                  22526 non-null  float64
#  6   Attendent_location               22436 non-null  string
#  7   Attendent_response_time          9658 non-null   string
#  8   Attendent_response_rate          9657 non-null   float64
#  9   Attendent_is_superAttendent      22552 non-null  bool
#  10  Attendent_Propertys_count        22526 non-null  float64
#  11  Attendent_total_Propertys_count  22526 non-null  float64
# ...

# %%
df.to_csv("PS.3.csv")
